# %% [markdown]
# # Handwritten Digit recognition using CNN

# %% [markdown]
# # import the libararies

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %% [markdown]
# # Preprocessing data

# %%
num_classes=10
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train = x_train/255
x_test = x_test/255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# # Create the model

# %%
batch_size = 128
num_classes = 10
epochs = 10
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss=keras.losses.categorical_crossentropy,optimizer=keras.optimizers.Adadelta(),metrics=['accuracy'])

# %% [markdown]
# # Train the model

# %%
hist=model.fit(x_train,y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")
model.save('mnist.h5')
print("Saving the model as mnist.h5")
# Out:
# Epoch 1/10
# 469/469 [==============================] - 80s 168ms/step - loss: 2.2881 - accuracy: 0.1423 - val_loss: 2.2635 - val_accuracy: 0.3644
# Epoch 2/10
# 469/469 [==============================] - 160s 342ms/step - loss: 2.2443 - accuracy: 0.2700 - val_loss: 2.2079 - val_accuracy: 0.5602
# Epoch 3/10
# 469/469 [==============================] - 270s 576ms/step - loss: 2.1838 - accuracy: 0.3907 - val_loss: 2.1294 - val_accuracy: 0.6116
# Epoch 4/10
# 469/469 [==============================] - 267s 567ms/step - loss: 2.0983 - accuracy: 0.4773 - val_loss: 2.0152 - val_accuracy: 0.6524
# Epoch 5/10
# 469/469 [==============================] - 245s 522ms/step - loss: 1.9688 - accuracy: 0.5475 - val_loss: 1.8463 - val_accuracy: 0.6947
# Epoch 6/10
# 469/469 [==============================] - 264s 563ms/step - loss: 1.7884 - accuracy: 0.6001 - val_loss: 1.6157 - val_accuracy: 0.7402
# Epoch 7/10
# 469/469 [==============================] - 274s 583ms/step - loss: 1.5642 - accuracy: 0.6421 - val_loss: 1.3502 - val_accuracy: 0.7741
# Epoch 8/10
# 469/469 [==============================] - 307s 655ms/step - loss: 1.3323 - accuracy: 0.6732 - val_loss: 1.1026 - val_accuracy: 0.8011
# Epoch 9/10
# 469/469 [==============================] - 294s 626ms/step - loss: 1.1440 - accuracy: 0.7008 - val_loss: 0.9143 - val_accuracy: 0.8147
# Epoch 10/10
# 469/469 [==============================] - 300s 638ms/step - loss: 1.0063 - accuracy: 0.7198 - val_loss: 0.7829 - val_accuracy: 0.8316
# The model has successfully trained
# C:\Users\karthi\anaconda3\envs\object\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Saving the model as mnist.h5

# %% [markdown]
# # Evaluate the model

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.7829153537750244
# Test accuracy: 0.83160001039505

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        320
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 64)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 12, 12, 64)        0
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_2 (Dense)             (None, 256)               2359552
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 2380938 (9.08 MB)
# Trainable params: 2380938 (9.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #  Predict digits

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Load the model
model = tf.keras.models.load_model('mnist.h5')

# Load MNIST data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_test = np.expand_dims(x_test, -1) / 255.0  # Normalize and add channel dimension

# Test the model with some test images
for i in range(10):
    img = x_test[i]
    label = y_test[i]
    img = np.expand_dims(img, 0)  # Add batch dimension
    prediction = model.predict(img)[0]
    predicted_class = np.argmax(prediction)
    probability = np.max(prediction)

    # Plot the image and prediction
    plt.imshow(img[0, :, :, 0], cmap='gray')
    plt.title(f'Label: {label}, Prediction: {predicted_class}, Probability: {probability:.2f}')
    plt.show()
# Out:
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step

# %% [markdown]
# # Increasing accuracy

# %% [markdown]
# #### We are doing hyperparameter tuning to increase accuracy

# %%
batch_size = 128
num_classes = 10
epochs = 25
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss=keras.losses.categorical_crossentropy,optimizer=keras.optimizers.Adadelta(),metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
hist=model.fit(x_train,y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")
# Out:
# Epoch 1/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 0.1369 - loss: 2.2898 - val_accuracy: 0.4248 - val_loss: 2.2370
# Epoch 2/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.2785 - loss: 2.2279 - val_accuracy: 0.6310 - val_loss: 2.1520
# Epoch 3/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.4179 - loss: 2.1428 - val_accuracy: 0.6903 - val_loss: 2.0322
# Epoch 4/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.5191 - loss: 2.0239 - val_accuracy: 0.7214 - val_loss: 1.8644
# Epoch 5/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5810 - loss: 1.8596 - val_accuracy: 0.7467 - val_loss: 1.6413
# Epoch 6/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.6199 - loss: 1.6524 - val_accuracy: 0.7768 - val_loss: 1.3849
# Epoch 7/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6550 - loss: 1.4246 - val_accuracy: 0.7964 - val_loss: 1.1417
# Epoch 8/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6868 - loss: 1.2238 - val_accuracy: 0.8119 - val_loss: 0.9493
# Epoch 9/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7083 - loss: 1.0671 - val_accuracy: 0.8268 - val_loss: 0.8100
# Epoch 10/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7336 - loss: 0.9460 - val_accuracy: 0.8375 - val_loss: 0.7112
# Epoch 11/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7467 - loss: 0.8666 - val_accuracy: 0.8460 - val_loss: 0.6409
# Epoch 12/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7628 - loss: 0.8032 - val_accuracy: 0.8547 - val_loss: 0.5881
# Epoch 13/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7705 - loss: 0.7546 - val_accuracy: 0.8630 - val_loss: 0.5472
# Epoch 14/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.7842 - loss: 0.7154 - val_accuracy: 0.8679 - val_loss: 0.5153
# Epoch 15/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7936 - loss: 0.6752 - val_accuracy: 0.8729 - val_loss: 0.4891
# Epoch 16/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7997 - loss: 0.6543 - val_accuracy: 0.8773 - val_loss: 0.4675
# Epoch 17/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8081 - loss: 0.6295 - val_accuracy: 0.8805 - val_loss: 0.4487
# Epoch 18/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8140 - loss: 0.6082 - val_accuracy: 0.8837 - val_loss: 0.4328
# Epoch 19/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8209 - loss: 0.5785 - val_accuracy: 0.8873 - val_loss: 0.4184
# Epoch 20/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8281 - loss: 0.5624 - val_accuracy: 0.8904 - val_loss: 0.4063
# Epoch 21/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8288 - loss: 0.5554 - val_accuracy: 0.8923 - val_loss: 0.3958
# Epoch 22/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8327 - loss: 0.5499 - val_accuracy: 0.8946 - val_loss: 0.3857
# Epoch 23/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8385 - loss: 0.5266 - val_accuracy: 0.8961 - val_loss: 0.3766
# Epoch 24/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8417 - loss: 0.5177 - val_accuracy: 0.8985 - val_loss: 0.3681
# Epoch 25/25
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8473 - loss: 0.5071 - val_accuracy: 0.9007 - val_loss: 0.3603
# The model has successfully trained

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
model.save('mnist.h5')
print("Saving the model as mnist.h5")

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.360291987657547
# Test accuracy: 0.9006999731063843

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 24, 24, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 12, 12, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 12, 12, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 9216)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │       2,359,552 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,142,816 (27.25 MB)
#  Trainable params: 2,380,938 (9.08 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 4,761,878 (18.17 MB)

# %%
import numpy as np
# Test the model with some test images
for i in range(10):
    img = x_test[i]
    label = y_test[i]
    img = np.expand_dims(img, 0)  # Add batch dimension
    prediction = model.predict(img)[0]
    predicted_class = np.argmax(prediction)
    probability = np.max(prediction)

    # Plot the image and prediction
    plt.imshow(img[0, :, :, 0], cmap='gray')
    plt.title(f'Label: {label}, Prediction: {predicted_class}, Probability: {probability:.2f}')
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Get the model's predictions
y_pred = model.predict(x_test)

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

# Print classification report
print(classification_report(y_true, y_pred_classes))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       980
#            1       0.95      0.98      0.96      1135
#            2       0.90      0.86      0.88      1032
#            3       0.89      0.89      0.89      1010
#            4       0.90      0.90      0.90       982
#            5       0.90      0.81      0.85       892
#            6       0.90      0.93      0.92       958
#            7       0.91      0.88      0.89      1028
#            8       0.85      0.87      0.86       974
#            9       0.87      0.89      0.88      1009
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.90      0.90     10000
# weighted avg       0.90      0.90      0.90     10000
